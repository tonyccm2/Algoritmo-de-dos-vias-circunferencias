# %% [markdown]
# <a href="https://colab.research.google.com/github/tonyccm2/Algoritmo-de-dos-vias-circunferencias/blob/master/algoritmo_de_dos_v%C3%ADas_para_circunferencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib.pyplot import imshow
from PIL import Image ,ImageDraw
import matplotlib.pyplot as plt

def ROUND(a):
	return int(a + 0.5)
 
 
#modululo de circumferencia 2 vias
def circulo2(cx,cy,r):
  img_draw.point((cx+r,cy),fill='black')
  img_draw.point((cx-r,cy),fill='black')
  x=r
  for x in range(-r,r):
    y=ROUND(np.sqrt(r**2-x**2))
    img_draw.point((cx+x,cy+y),fill='red')
    img_draw.point((cx+x,cy-y),fill='red')


#diibujar camvas
blank_image=Image.new('RGB', (100,100), 'white')
img_draw=ImageDraw.Draw(blank_image)


circulo2(50,50,40)


blank_image.save('drawn_image.jpg')
# Open your file image using the path
img = Image.open('drawn_image.jpg')

# Since plt knows how to handle instance of the Image class, just input your loaded image to imshow method
plt.imshow(img,origin='lower')
